# %% [markdown]
# # 동국대학교 교육대학원
# ## 머신러닝을위한수학과파이썬기초 - 01주차 실습
# - 담당: 동국대학교 교육대학원 AI융합교육전공
# - 내용: 파이썬 및 NumPy 기초 연산

# %%
import numpy as np
print('NumPy Version:', np.__version__)

# 1. 벡터 생성
v = np.array([1, 2, 3])
print('Vector:', v)
